# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import warnings
warnings.simplefilter('ignore')

import gc

from os import path
import sys
sys.path.append(path.abspath('..'))

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

# %%
# !ls ../weights/lrf_config_1/train
# Out:
# events.out.tfevents.1658755512.sergey

# %%
fname = '../weights/lrf_config_1/train/events.out.tfevents.1658755512.sergey'
data = event_accumulator.EventAccumulator(fname)
_ = data.Reload()

loss = np.array([scalar.value for scalar in data.Scalars('loss/batch')])
lr = np.array([scalar.value for scalar in data.Scalars('lr/batch')])

# %%
# выбрал диапазон от 1е-5 до 1e-3
plt.xscale('log')
plt.grid(axis='both')
_ = plt.plot(lr, loss)

# %%
# !ls ../weights/lrf_config_2/train
# Out:
# events.out.tfevents.1658756803.sergey

# %%
fname = '../weights/lrf_config_2/train/events.out.tfevents.1658756803.sergey'
data = event_accumulator.EventAccumulator(fname)
_ = data.Reload()

loss = np.array([scalar.value for scalar in data.Scalars('loss/batch')])
lr = np.array([scalar.value for scalar in data.Scalars('lr/batch')])

# %%
# Здесь диапазон lr определить сложно, в таком случае лучше отталкиваться от предыдущей тренировки и экспериментировать
plt.xscale('log')
plt.grid(axis='both')
_ = plt.plot(lr, loss)
